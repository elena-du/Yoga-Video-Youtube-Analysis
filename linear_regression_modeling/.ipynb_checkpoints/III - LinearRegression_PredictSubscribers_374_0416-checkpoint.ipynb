# %%
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

import statsmodels.api as sm
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import lars_path

# %matplotlib inline
sns.set()

# %%
with open('../feature_engineering/video_channel_df_8162_fin.pkl', 'rb') as picklefile:
    df = pickle.load(picklefile)

# %%
df.shape
# Out:
# (8162, 19)

# %%
df.columns
# Out:
# Index(['views_video', 'video_order_num', 'duration_sec', 'likes', 'dislikes',
#        'video_desc_length', 'subscriber_count', 'total_views_channel',
#        'n_featured_channels', 'n_promo_links', 'channel_desc_length',
#        'channel_age_days', 'video_age_days', 'delivery_method_Published',
#        'delivery_method_Streamed live', 'sentiment_score_channel_desc',
#        'sentiment_score_video_desc', 'channel_URL', 'channel_name'],
#       dtype='object')

# %%
df_channel_vars = df[['subscriber_count', 'total_views_channel',
       'n_featured_channels', 'n_promo_links', 'channel_desc_length',
       'channel_age_days', 'sentiment_score_channel_desc', 'channel_URL', 'channel_name']]

# %%
df_channel_vars = df_channel_vars.drop_duplicates()

# %%
len(list(df['channel_URL'].unique()))
# Out:
# 374

# %%
df_channel = (df
 .groupby(['channel_URL'])[['views_video', 'video_order_num', 'video_desc_length', 
                            'likes', 'dislikes', 'duration_sec', 
                            'video_age_days', 'sentiment_score_video_desc']]
 .agg({
     'views_video':'mean',
     'video_order_num':'count',
     'video_desc_length': 'mean',
     'likes':'sum',
     'dislikes':'sum',
     'duration_sec':'mean',
     'video_age_days':'mean',
     'sentiment_score_video_desc':'mean'
     
 })
)

# %%
df_channel.rename(columns={'views_video':'views_video_mean',
     'video_order_num':'video_order_num_count',
     'video_desc_length': 'video_desc_length_mean',
     'likes':'likes_sum',
     'dislikes':'dislikes_sum',
     'duration_sec':'duration_sec_mean',
     'video_age_days':'video_age_days_mean',
     'sentiment_score_video_desc':'sentiment_score_video_desc_mean'}, 
          inplace=True)

# %%
df_channel.shape
# Out:
# (374, 8)

# %%
df_channel.head()
# Out:
#                                                     views_video_mean  \
# channel_URL
# https://www.youtube.com/channel/UC-7Q2AdnLm4n8U...      13223.250000
# https://www.youtube.com/channel/UC-OCmpA4oA2HgQ...       5573.812500
# https://www.youtube.com/channel/UC-enqt3oO6foLM...       8159.956522
# https://www.youtube.com/channel/UC0CPgd4W4_Cxh6...       4368.100000
# https://www.youtube.com/channel/UC0NbJtWBuc8fgv...       3451.566667
#
#                                                     video_order_num_count  \
# channel_URL
# https://www.youtube.com/channel/UC-7Q2AdnLm4n8U...                      4
# https://www.youtube.com/channel/UC-OCmpA4oA2HgQ...                     32
# https://www.youtube.com/channel/UC-enqt3oO6foLM...                     23
# https://www.youtube.com/channel/UC0CPgd4W4_Cxh6...                     30
# https://www.youtube.com/channel/UC0NbJtWBuc8fgv...                     30
#
#                                                     video_desc_length_mean  \
# channel_URL
# https://www.youtube.com/channel/UC-7Q2AdnLm4n8U...              235.500000
# https://www.youtube.com/channel/UC-OCmpA4oA2HgQ...              135.062500
# https://www.youtube.com/channel/UC-enqt3oO6foLM...              240.739130
# https://www.youtube.com/channel/UC0CPgd4W4_Cxh6...             1510.100000
# https://www.youtube.com/channel/UC0NbJtWBuc8fgv...              558.366667
#
#                                                     likes_sum  dislikes_sum  \
# channel_URL
# https://www.youtube.com/channel/UC-7Q2AdnLm4n8U...       75.0           3.0
# https://www.youtube.com/channel/UC-OCmpA4oA2HgQ...       74.0           4.0
# https://www.youtube.com/channel/UC-enqt3oO6foLM...      662.0          13.0
# https://www.youtube.com/channel/UC0CPgd4W4_Cxh6...      414.0          32.0
# https://www.youtube.com/channel/UC0NbJtWBuc8fgv...      284.0          10.0
#
#                                                     duration_sec_mean  \
# channel_URL
# https://www.youtube.com/channel/UC-7Q2AdnLm4n8U...         206.250000
# https://www.youtube.com/channel/UC-OCmpA4oA2HgQ...         260.750000
# https://www.youtube.com/channel/UC-enqt3oO6foLM...        2704.739130
# https://www.youtube.com/channel/UC0CPgd4W4_Cxh6...         194.433333
# https://www.youtube.com/channel/UC0NbJtWBuc8fgv...         666.333333
#
#                                                     video_age_days_mean  \
# channel_URL
# https://www.youtube.com/channel/UC-7Q2AdnLm4n8U...          1356.000000
# https://www.youtube.com/channel/UC-OCmpA4oA2HgQ...          1819.250000
# https://www.youtube.com/channel/UC-enqt3oO6foLM...           112.347826
# https://www.youtube.com/channel/UC0CPgd4W4_Cxh6...           141.033333
# https://www.youtube.com/channel/UC0NbJtWBuc8fgv...           539.966667
#
#                                                     sentiment_score_video_desc_mean
# channel_URL
# https://www.youtube.com/channel/UC-7Q2AdnLm4n8U...                         5.250000
# https://www.youtube.com/channel/UC-OCmpA4oA2HgQ...                         1.281250
# https://www.youtube.com/channel/UC-enqt3oO6foLM...                        -0.347826
# https://www.youtube.com/channel/UC0CPgd4W4_Cxh6...                        10.233333
# https://www.youtube.com/channel/UC0NbJtWBuc8fgv...                         6.233333

# %%
df_channel_vars.set_index('channel_URL', inplace=True)

# %%
df = df_channel.join(df_channel_vars)

# %%
df.shape
# Out:
# (374, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 374 entries, https://www.youtube.com/channel/UC-7Q2AdnLm4n8Uhii4cXKPA to https://www.youtube.com/user/zaoyoga
# Data columns (total 16 columns):
# views_video_mean                   374 non-null float64
# video_order_num_count              374 non-null int64
# video_desc_length_mean             374 non-null float64
# likes_sum                          374 non-null float64
# dislikes_sum                       374 non-null float64
# duration_sec_mean                  374 non-null float64
# video_age_days_mean                374 non-null float64
# sentiment_score_video_desc_mean    374 non-null float64
# subscriber_count                   374 non-null float64
# total_views_channel                374 non-null float64
# n_featured_channels                374 non-null float64
# n_promo_links                      374 non-null float64
# channel_desc_length                374 non-null float64
# channel_age_days                   374 non-null float64
# sentiment_score_channel_desc       374 non-null float64
# channel_name                       374 non-null object
# dtypes: float64(14), int64(1), object(1)
# memory usage: 59.7+ KB

# %%
df.columns
# Out:
# Index(['views_video_mean', 'video_order_num_count', 'video_desc_length_mean',
#        'likes_sum', 'dislikes_sum', 'duration_sec_mean', 'video_age_days_mean',
#        'sentiment_score_video_desc_mean', 'subscriber_count',
#        'total_views_channel', 'n_featured_channels', 'n_promo_links',
#        'channel_desc_length', 'channel_age_days',
#        'sentiment_score_channel_desc', 'channel_name'],
#       dtype='object')

# %%
#X_array = df.loc[:,'video_order_num':'sentiment_score_video_desc'].values.reshape(-1, 1)
X_df = df[['views_video_mean', 'video_order_num_count', 'video_desc_length_mean',
       'likes_sum', 'dislikes_sum', 'duration_sec_mean', 'video_age_days_mean',
       'sentiment_score_video_desc_mean',
       'total_views_channel', 'n_featured_channels', 'n_promo_links',
       'channel_desc_length', 'channel_age_days',
       'sentiment_score_channel_desc']]
y = df['subscriber_count']

# %% [markdown]
# ## Baseline linear regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df, y, 
                                                    test_size=0.3, 
                                                    random_state=42)

vanilla_LR = LinearRegression()
vanilla_LR.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
vanilla_LR.score(X_train,y_train)
# Out:
# 0.8140665369373656

# %%
vanilla_LR.score(X_test,y_test)
# Out:
# 0.6212065273714921

# %% [markdown]
# ## Study Influence of Outliers on Best Model

# %%
df['res'] = abs(vanilla_LR.predict(X_df)-y)

# %%
df['res'].describe()
# Out:
# count    3.740000e+02
# mean     6.178386e+04
# std      2.422119e+05
# min      2.310338e+02
# 25%      1.091226e+04
# 50%      2.433422e+04
# 75%      4.815081e+04
# max      4.147144e+06
# Name: res, dtype: float64

# %%
plt.boxplot(df['res']);

# %%
#outliers in terms of residuals
df[df['res'] > 1.233987e+05]
# Out:
#                                                     views_video_mean  \
# channel_URL
# https://www.youtube.com/channel/UC4dlco6FzS-AJF...      1.076644e+08
# https://www.youtube.com/channel/UCCOOToZSV4lDrb...      1.833935e+04
# https://www.youtube.com/channel/UCTlmEOYH5tLJQP...      2.793593e+06
# https://www.youtube.com/channel/UCYmM9DXH1XC1Zy...      7.378941e+03
# https://www.youtube.com/channel/UCbEVE94TB2imHI...      2.660193e+06
# https://www.youtube.com/channel/UCiB2eHp-Mx97LG...      1.113660e+08
# https://www.youtube.com/channel/UCoI2HuJP6NHFk9...      3.909658e+06
# https://www.youtube.com/channel/UCod2Gi9j8THW1h...      1.626637e+06
# https://www.youtube.com/channel/UCq6iAv6Ydn5-cc...      1.761834e+06
# https://www.youtube.com/channel/UCzIXSdwWGfMoc3...      1.521406e+05
# https://www.youtube.com/user/BrettLarkinYoga            4.993667e+04
# https://www.youtube.com/user/Dallapage                  1.873760e+05
# https://www.youtube.com/user/KinoYoga                   1.807990e+05
# https://www.youtube.com/user/SarahBethShow              5.861985e+05
# https://www.youtube.com/user/Sukadev108                 1.405333e+03
# https://www.youtube.com/user/TaraStilesYoga             2.080673e+05
# https://www.youtube.com/user/VideoJug                   1.550548e+05
# https://www.youtube.com/user/blogilates                 3.305534e+06
# https://www.youtube.com/user/butlerl2                   1.452196e+05
# https://www.youtube.com/user/faceyogamethod             5.772893e+04
# https://www.youtube.com/user/lesleyfightmaster          2.506267e+05
# https://www.youtube.com/user/satyogainstitute           2.662087e+04
# https://www.youtube.com/user/shilpayoga                 1.726841e+07
# https://www.youtube.com/user/traviseliotonline          2.143017e+05
# https://www.youtube.com/user/yogalanbcn                 1.020565e+06
# https://www.youtube.com/user/yogamonki                  1.055493e+06
# https://www.youtube.com/user/yogawithadriene            4.996838e+06
# https://www.youtube.com/user/yogawithkassandra          7.623503e+05
# https://www.youtube.com/user/yogawithtim                2.794010e+05
# https://www.youtube.com/user/yogayak                    2.685225e+05
#
#                                                     video_order_num_count  \
# channel_URL
# https://www.youtube.com/channel/UC4dlco6FzS-AJF...                      3
# https://www.youtube.com/channel/UCCOOToZSV4lDrb...                     23
# https://www.youtube.com/channel/UCTlmEOYH5tLJQP...                     31
# https://www.youtube.com/channel/UCYmM9DXH1XC1Zy...                     17
# https://www.youtube.com/channel/UCbEVE94TB2imHI...                     30
# https://www.youtube.com/channel/UCiB2eHp-Mx97LG...                      5
# https://www.youtube.com/channel/UCoI2HuJP6NHFk9...                     26
# https://www.youtube.com/channel/UCod2Gi9j8THW1h...                     30
# https://www.youtube.com/channel/UCq6iAv6Ydn5-cc...                     30
# https://www.youtube.com/channel/UCzIXSdwWGfMoc3...                     30
# https://www.youtube.com/user/BrettLarkinYoga                            9
# https://www.youtube.com/user/Dallapage                                 24
# https://www.youtube.com/user/KinoYoga                                  24
# https://www.youtube.com/user/SarahBethShow                             17
# https://www.youtube.com/user/Sukadev108                                30
# https://www.youtube.com/user/TaraStilesYoga                            30
# https://www.youtube.com/user/VideoJug                                  30
# https://www.youtube.com/user/blogilates                                17
# https://www.youtube.com/user/butlerl2                                  23
# https://www.youtube.com/user/faceyogamethod                            30
# https://www.youtube.com/user/lesleyfightmaster                         21
# https://www.youtube.com/user/satyogainstitute                          23
# https://www.youtube.com/user/shilpayoga                                30
# https://www.youtube.com/user/traviseliotonline                         30
# https://www.youtube.com/user/yogalanbcn                                20
# https://www.youtube.com/user/yogamonki                                  1
# https://www.youtube.com/user/yogawithadriene                            9
# https://www.youtube.com/user/yogawithkassandra                         10
# https://www.youtube.com/user/yogawithtim                                3
# https://www.youtube.com/user/yogayak                                   30
#
#                                                     video_desc_length_mean  \
# channel_URL
# https://www.youtube.com/channel/UC4dlco6FzS-AJF...             3135.666667
# https://www.youtube.com/channel/UCCOOToZSV4lDrb...             2577.260870
# https://www.youtube.com/channel/UCTlmEOYH5tLJQP...              124.096774
# https://www.youtube.com/channel/UCYmM9DXH1XC1Zy...             2075.058824
# https://www.youtube.com/channel/UCbEVE94TB2imHI...              448.300000
# https://www.youtube.com/channel/UCiB2eHp-Mx97LG...              577.600000
# https://www.youtube.com/channel/UCoI2HuJP6NHFk9...              254.384615
# https://www.youtube.com/channel/UCod2Gi9j8THW1h...             1722.066667
# https://www.youtube.com/channel/UCq6iAv6Ydn5-cc...              444.366667
# https://www.youtube.com/channel/UCzIXSdwWGfMoc3...             2002.000000
# https://www.youtube.com/user/BrettLarkinYoga                   2789.333333
# https://www.youtube.com/user/Dallapage                          350.333333
# https://www.youtube.com/user/KinoYoga                          1602.625000
# https://www.youtube.com/user/SarahBethShow                     2175.941176
# https://www.youtube.com/user/Sukadev108                         719.000000
# https://www.youtube.com/user/TaraStilesYoga                     231.000000
# https://www.youtube.com/user/VideoJug                           652.933333
# https://www.youtube.com/user/blogilates                        2801.000000
# https://www.youtube.com/user/butlerl2                          2766.478261
# https://www.youtube.com/user/faceyogamethod                     460.633333
# https://www.youtube.com/user/lesleyfightmaster                 2061.095238
# https://www.youtube.com/user/satyogainstitute                  4135.608696
# https://www.youtube.com/user/shilpayoga                         804.766667
# https://www.youtube.com/user/traviseliotonline                 3917.533333
# https://www.youtube.com/user/yogalanbcn                        1204.900000
# https://www.youtube.com/user/yogamonki                          174.000000
# https://www.youtube.com/user/yogawithadriene                   1990.000000
# https://www.youtube.com/user/yogawithkassandra                 3388.300000
# https://www.youtube.com/user/yogawithtim                        942.333333
# https://www.youtube.com/user/yogayak                           3361.733333
#
#                                                     likes_sum  dislikes_sum  \
# channel_URL
# https://www.youtube.com/channel/UC4dlco6FzS-AJF
\
# channel_URL
# https://www.youtube.com/channel/UC4dlco6FzS-AJF...                           0.0
# https://www.youtube.com/channel/UCCOOToZSV4lDrb...                          15.0
# https://www.youtube.com/channel/UCTlmEOYH5tLJQP...                           0.0
# https://www.youtube.com/channel/UCYmM9DXH1XC1Zy...                           7.0
# https://www.youtube.com/channel/UCbEVE94TB2imHI...                           6.0
# https://www.youtube.com/channel/UCiB2eHp-Mx97LG...                           0.0
# https://www.youtube.com/channel/UCoI2HuJP6NHFk9...                           2.0
# https://www.youtube.com/channel/UCod2Gi9j8THW1h...                          -2.0
# https://www.youtube.com/channel/UCq6iAv6Ydn5-cc...                           7.0
# https://www.youtube.com/channel/UCzIXSdwWGfMoc3...                           1.0
# https://www.youtube.com/user/BrettLarkinYoga                                14.0
# https://www.youtube.com/user/Dallapage                                       2.0
# https://www.youtube.com/user/KinoYoga                                        7.0
# https://www.youtube.com/user/SarahBethShow                                  11.0
# https://www.youtube.com/user/Sukadev108                                      4.0
# https://www.youtube.com/user/TaraStilesYoga                                 15.0
# https://www.youtube.com/user/VideoJug                                       11.0
# https://www.youtube.com/user/blogilates                                      8.0
# https://www.youtube.com/user/butlerl2                                       15.0
# https://www.youtube.com/user/faceyogamethod                                  3.0
# https://www.youtube.com/user/lesleyfightmaster                              21.0
# https://www.youtube.com/user/satyogainstitute                                4.0
# https://www.youtube.com/user/shilpayoga                                     22.0
# https://www.youtube.com/user/traviseliotonline                               4.0
# https://www.youtube.com/user/yogalanbcn                                      2.0
# https://www.youtube.com/user/yogamonki                                       2.0
# https://www.youtube.com/user/yogawithadriene                                18.0
# https://www.youtube.com/user/yogawithkassandra                               5.0
# https://www.youtube.com/user/yogawithtim                                    12.0
# https://www.youtube.com/user/yogayak                                         0.0
#
#                                                                       channel_name  \
# channel_URL
# https://www.youtube.com/channel/UC4dlco6FzS-AJF...
# https://www.youtube.com/channel/UCCOOToZSV4lDrb...       FREE 7 Day Yin Immersion!
# https://www.youtube.com/channel/UCTlmEOYH5tLJQP...                         Patreon
# https://www.youtube.com/channel/UCYmM9DXH1XC1Zy...                    Learn Online
# https://www.youtube.com/channel/UCbEVE94TB2imHI...                         Twitter
# https://www.youtube.com/channel/UCiB2eHp-Mx97LG...
# https://www.youtube.com/channel/UCoI2HuJP6NHFk9...                        Facebook
# https://www.youtube.com/channel/UCod2Gi9j8THW1h...          Fotos e Dicas de Yoga!
# https://www.youtube.com/channel/UCq6iAv6Ydn5-cc...
# https://www.youtube.com/channel/UCzIXSdwWGfMoc3...                              IG
# https://www.youtube.com/user/BrettLarkinYoga                      CHAKRA CHALLENGE
# https://www.youtube.com/user/Dallapage                                DDPY Website
# https://www.youtube.com/user/KinoYoga                                 KinoYoga.com
# https://www.youtube.com/user/SarahBethShow                       SarahBethYoga APP
# https://www.youtube.com/user/Sukadev108             Klicke hier für weitere Infos!
# https://www.youtube.com/user/TaraStilesYoga                            Tara Stiles
# https://www.youtube.com/user/VideoJug                                 videojug.com
# https://www.youtube.com/user/blogilates                                   Text me!
# https://www.youtube.com/user/butlerl2                                Leigha Butler
# https://www.youtube.com/user/faceyogamethod                       Face Yoga Method
# https://www.youtube.com/user/lesleyfightmaster                             Website
# https://www.youtube.com/user/satyogainstitute                              Website
# https://www.youtube.com/user/shilpayoga                       Shilpa Shetty Kundra
# https://www.youtube.com/user/traviseliotonline                           Instagram
# https://www.youtube.com/user/yogalanbcn                                     Mi web
# https://www.youtube.com/user/yogamonki                                 Yoga Flocke
# https://www.youtube.com/user/yogawithadriene                   YogaWithAdriene.com
# https://www.youtube.com/user/yogawithkassandra              MORNING YOGA CHALLENGE
# https://www.youtube.com/user/yogawithtim                                 Yoga Dose
# https://www.youtube.com/user/yogayak
#
#                                                              res
# channel_URL
# https://www.youtube.com/channel/UC4dlco6FzS-AJF...  3.075967e+05
# https://www.youtube.com/channel/UCCOOToZSV4lDrb...  1.463111e+05
# https://www.youtube.com/channel/UCTlmEOYH5tLJQP...  3.113700e+05
# https://www.youtube.com/channel/UCYmM9DXH1XC1Zy...  1.617713e+05
# https://www.youtube.com/channel/UCbEVE94TB2imHI...  2.368418e+05
# https://www.youtube.com/channel/UCiB2eHp-Mx97LG...  2.891685e+05
# https://www.youtube.com/channel/UCoI2HuJP6NHFk9...  3.593633e+05
# https://www.youtube.com/channel/UCod2Gi9j8THW1h...  1.622119e+05
# https://www.youtube.com/channel/UCq6iAv6Ydn5-cc...  1.459863e+05
# https://www.youtube.com/channel/UCzIXSdwWGfMoc3...  1.367555e+05
# https://www.youtube.com/user/BrettLarkinYoga        1.344211e+05
# https://www.youtube.com/user/Dallapage              2.923262e+05
# https://www.youtube.com/user/KinoYoga               2.612833e+05
# https://www.youtube.com/user/SarahBethShow          3.174781e+05
# https://www.youtube.com/user/Sukadev108             1.368016e+05
# https://www.youtube.com/user/TaraStilesYoga         1.676257e+05
# https://www.youtube.com/user/VideoJug               1.508616e+06
# https://www.youtube.com/user/blogilates             1.165939e+06
# https://www.youtube.com/user/butlerl2               2.311388e+05
# https://www.youtube.com/user/faceyogamethod         2.506679e+05
# https://www.youtube.com/user/lesleyfightmaster      1.918663e+05
# https://www.youtube.com/user/satyogainstitute       1.756952e+05
# https://www.youtube.com/user/shilpayoga             2.429098e+05
# https://www.youtube.com/user/traviseliotonline      1.611068e+05
# https://www.youtube.com/user/yogalanbcn             4.019179e+05
# https://www.youtube.com/user/yogamonki              2.698874e+05
# https://www.youtube.com/user/yogawithadriene        4.147144e+06
# https://www.youtube.com/user/yogawithkassandra      2.839174e+05
# https://www.youtube.com/user/yogawithtim            1.302495e+05
# https://www.youtube.com/user/yogayak                7.269776e+05

# %%
df_no_outliers = df[df['res'] < 1.233987e+05]  ## keep 6

# %%
df_no_outliers.shape ##removed 2573 observations with greatest residual values
# Out:
# (344, 17)

# %%
X_df_no_outliers = df_no_outliers[['views_video_mean', 'video_order_num_count', 'video_desc_length_mean',
       'likes_sum', 'dislikes_sum', 'duration_sec_mean', 'video_age_days_mean',
       'sentiment_score_video_desc_mean',
       'total_views_channel', 'n_featured_channels', 'n_promo_links',
       'channel_desc_length', 'channel_age_days',
       'sentiment_score_channel_desc']]
y_no_outliers = df_no_outliers['subscriber_count']

# %%
plt.boxplot(df_no_outliers['res']);

# %% [markdown]
# ## Baseline Regression with Outliers Removed

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df_no_outliers, 
                                                    y_no_outliers, 
                                                    test_size=0.3, 
                                                    random_state=42)

# %%
vanilla_LR_no = LinearRegression()
vanilla_LR_no.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
vanilla_LR_no.score(X_train,y_train) #--> outliers
# Out:
# 0.8568107359625832

# %%
vanilla_LR_no.score(X_test,y_test)
# Out:
# 0.8195952610890976

# %% [markdown]
# ## Regularizing, keeping Original Features

# %%
std = StandardScaler()
std.fit(X_train)
X_tr = std.transform(X_train)
X_te = std.transform(X_test)#numpy.ndarray

# %%
alphavec = 10**np.linspace(-6,4,200)
lasso_model = LassoCV(alphas = alphavec, cv=5)
lasso_model.fit(X_tr, y_train);

# %%
lasso_model.score(X_tr,y_train)
# Out:
# 0.8378352598362527

# %%
lasso_model.alpha_
# Out:
# 2800.5038941836365

# %%
lasso_model.score(X_te,y_test) ##doesnt work as it is about variation in the data,
# Out:
# 0.8292018813881007

# %% [markdown]
# ## Add polynomial and interaction terms

# %%
pf = PolynomialFeatures(degree=2)
orig_features = X_df_no_outliers.columns
pf.fit(df[orig_features_h])
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False,
#                    order='C')

# %%
feat_array = pf.transform(df_no_outliers[orig_features])
feat_array = pd.DataFrame(feat_array, columns = pf.get_feature_names(input_features=orig_features))

# %%
X_train, X_test, y_train, y_test = train_test_split(feat_array, y_no_outliers, 
                                                    test_size=0.3, 
                                                    random_state=42)
model_w_poly_feat = LinearRegression()
model_w_poly_feat.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model_w_poly_feat.score(X_train,y_train)
# Out:
# 0.966348260281481

# %%
model_w_poly_feat.score(X_test,y_test) #overfit alert! regularize
# Out:
# -216.92998845229172

# %%
std = StandardScaler()
std.fit(X_train)
X_tr = std.transform(X_train)
X_te = std.transform(X_test)#numpy.ndarray
alphavec = 10**np.linspace(-10,10,200)
lasso_model_w_poly_feat_h = LassoCV(alphas = alphavec, cv=5)
lasso_model_w_poly_feat_h.fit(X_tr, y_train);
# Out:
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48928144.42586517, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141945485.91957855, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 208554024.18447304, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140842211.924078, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 295856584.44607925, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 785622998.7645493, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1237029154.4553957, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1409845449.9099894, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1338006902.179616, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1315718358.9671793, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1424650794.2436433, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1491778103.4846263, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1533909372.854693, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1575118016.1182933, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1589680547.9944081, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1559279664.9551249, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1539085880.5111287, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1522057493.995608, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1465064069.5302253, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1441473485.9348197, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1408014054.4993808, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1486098611.4129574, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1544521669.030574, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1596139187.050329, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1627814120.9368637, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1654843318.3381708, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1677136736.2608933, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1695950596.2378342, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1712077037.3605154, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1725921071.4678328, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1737699794.4814901, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1747562948.5034661, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1755655062.210246, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1762138981.8167007, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1767196773.1415675, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1771020222.045277, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1773798999.9541445, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1775761273.4236739, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1776936635.3466458, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1777557712.176042, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1777732227.665996, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1777553122.1297736, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1777097221.548504, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1776426692.3946886, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1775591296.1605778, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1774631720.6320894, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1773577136.384086, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1772453639.213665, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1771280510.9291492, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1770073173.4736679, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1768843913.6796975, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1767602516.294615, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1766356796.5176775, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1765113022.960587, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1763876293.920619, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1762650729.6944342, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1761439559.313671, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1760245502.6455235, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1759070832.9132519, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1757917416.6880271, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1756786742.9712505, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1755680071.5496545, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1754598433.6287415, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1753542666.4151702, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1752513439.6730676, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1751511277.4436393, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1750536575.6949365, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1749589617.6639466, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1748670584.411409, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1747779564.791993, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1746916570.1724203, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1746081575.6646545, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1745274371.7826056, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1744494761.2307184, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1743742489.3623438, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1743017248.0366795, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1742318680.480782, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1741646385.9494781, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1740999924.475155, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1740378821.0397441, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1739782569.558408, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1739210636.4524467, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1738662464.722081, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1738137476.9975896, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1737635078.8426077, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1737154661.8635554, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1736695606.5605376, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1736257284.916797, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1735839063.132993, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1735440303.8500059, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1735060368.3051236, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1734698618.475288, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1734354419.019683, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1734027138.8217578, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1733716152.6808183, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1733420842.7100997, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1733140599.8318062, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1732874824.5238073, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1732622928.3076384, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1732384334.3385131, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1732158478.3327718, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1731944809.3557842, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1731742790.1949868, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1731551897.9426875, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1731371624.393479, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1731201476.469022, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1731040976.1012924, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730889660.935353, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730747083.8763084, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730612813.3827026, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730486433.412085, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730367543.3859375, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730255757.9050314, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730150706.774041, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730052034.5558417, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1729959400.6348357, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1729872478.5537922, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1729790956.1455834, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1729714534.8926942, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1729642929.7103817, tolerance: 47650593.718125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217406966.44213486, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327452793.6084404, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215685202.92355728, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 397156647.9849205, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 211221221.69118118, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 222951817.47583008, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 295450117.19973373, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 350762451.1034527, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 629996009.2457371, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 921766063.5725279, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134687346.4817133, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1545371308.9518995, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2240386267.6834784, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2705239500.004884, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2914951321.079832, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3030335132.2051735, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3115864986.068918, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3165188330.070809, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3304419175.753029, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3410413566.4976587, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3497565298.102239, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3563351417.077342, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3605285524.3197093, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3624737849.6141644, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3648333128.7976317, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3659749273.659671, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3663367251.9846506, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3666029331.5766087, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3666328957.4576287, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3666522390.7272997, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3668809437.709552, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3668318185.1350517, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3665953761.9925723, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3662248103.6427245, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3657668710.8854694, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3652572956.556929, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3647134675.2395544, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3641663780.4370794, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3636207116.789929, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3630846467.3949018, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3625642263.5836415, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3620639012.0647883, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3615865547.885708, tolerance: 49685334.550000004
#   tol, rng, random, positive)
# ...
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231295886.542925, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231308665.9321976, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231314280.867783, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231314390.6881495, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231310320.0856385, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231303124.9502425, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231293645.3313384, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231282547.59337, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231270358.4317145, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231257492.06161, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231244272.265522, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231230950.0772333, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231217718.095355, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231204722.0716844, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231192070.1593213, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231179840.6457767, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231168087.929436, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231156847.566715, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231146140.2660394, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231135975.1033874, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231126352.214372, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231117264.8204317, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231108701.021343, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231100645.0896754, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231093078.5988164, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231085981.334173, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231079331.8484697, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231073108.1512656, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231067288.0737534, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231061849.5484123, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231056770.931698, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231052031.1149507, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231047609.752757, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231043487.2499604, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231039644.8551345, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231036064.7655673, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231032730.020987, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231029624.6451564, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231026733.4579954, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231024042.2598214, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231021537.643807, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231019206.9951873, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231017038.5299945, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231015021.210933, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231013144.6790767, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231011399.2727385, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231009775.9566402, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231008266.2836266, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231006862.389908, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231005556.9263043, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231004343.063721, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231003214.3847775, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231002164.970801, tolerance: 37432169.48578125
#   tol, rng, random, positive)
# /Users/elena/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3231001189.2907195, tolerance: 37432169.48578125
#   tol, rng, random, positive)

# %%
lasso_model_w_poly_feat_h.score(X_tr,y_train) ##note:ridge gives slightly worse result
# Out:
# 0.8293874097244309

# %%
lasso_model_w_poly_feat_h.alpha_
# Out:
# 5872.786613189489

# %%
lasso_model_w_poly_feat_h.score(X_te,y_test)
# Out:
# 0.8064510521183793

# %%
coefs = list(zip(X_train.columns, lasso_model_w_poly_feat_h.coef_))

# %%
df_coefs = pd.DataFrame(coefs, columns=['variable', 'coefficient'])
df_coefs
# Out:
#                                              variable  coefficient
# 0                                                   1          0.0
# 1                                    views_video_mean         -0.0
# 2                               video_order_num_count         -0.0
# 3                              video_desc_length_mean          0.0
# 4                                           likes_sum          0.0
# ..                                                ...          ...
# 115              channel_desc_length channel_age_days          0.0
# 116  channel_desc_length sentiment_score_channel_desc         -0.0
# 117                                channel_age_days^2          0.0
# 118     channel_age_days sentiment_score_channel_desc          0.0
# 119                    sentiment_score_channel_desc^2         -0.0
#
# [120 rows x 2 columns]

# %%
df_coefs[df_coefs['coefficient']!=0.0]
# Out:
#                             variable   coefficient
# 9                total_views_channel  36740.757195
# 43  video_desc_length_mean likes_sum    689.646764
# 60     likes_sum n_featured_channels   1635.523555
# 61           likes_sum n_promo_links   2227.743396

# %%
#81, 62 --> #83,81
